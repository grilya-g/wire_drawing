# %%
import pandas as pd
import numpy as np
import os
import sys

sys.path.append("../..")
from analysis_functions import *

# %%
# Загрузка данных
X_stress_components_new = opener("X_stress_components_new", path_import="../../resourses")
X_strain_components_new = opener("X_strain_components_new", path_import="../../resourses")
y_stress_components_new = opener("y_stress_components_new", path_import="../../resourses")
y_strain_components_new = opener("y_strain_components_new", path_import="../../resourses")
# X_stress_components_other = opener('X_stress_components_other')
# X_strain_components_other = opener('X_strain_components_other')
# y_stress_components_other = opener('y_stress_components_other')
# y_strain_components_other = opener('y_strain_components_other')
# Out:
# ../../resourses/X_stress_components_new.pkl
# ../../resourses/X_strain_components_new.pkl
# ../../resourses/y_stress_components_new.pkl
# ../../resourses/y_strain_components_new.pkl

# %%
component_num = 2

X, y = (X_stress_components_new[component_num], 
        y_stress_components_new[component_num])

# %% [markdown]
# ## Простое обучение

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Разделение данных на обучающую, валидационную и тестовую выборки
cur_X_train, cur_X_test, cur_y_train, cur_y_test = split_transform_one_comp_train_test(
    X, y
)

# Обучение модели
model = GradientBoostingRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    loss="squared_error",
    random_state=RANDOM_STATE,
)
model.fit(cur_X_train, cur_y_train)

# Предсказание
cur_y_pred = model.predict(cur_X_test)

# Оценка качества
rmse = np.sqrt(mean_squared_error(cur_y_test, cur_y_pred))
print(f"RMSE test: {rmse:.2f}")

# На трейне
cur_y_pred_train = model.predict(cur_X_train)
rmse_train = np.sqrt(mean_squared_error(cur_y_train, cur_y_pred_train))
print(f"RMSE train: {rmse_train:.2f}")
# Out:
# RMSE test: 8.69
# RMSE train: 8.66

# %%
import matplotlib.pyplot as plt

# Predicting the values
cur_y_pred = model.predict(cur_X_test)

# Plotting the results
plt.figure(figsize=(7, 6))
plt.scatter(cur_y_test, cur_y_pred, alpha=0.5, label="Predicted vs Actual")
plt.plot(
    [min(cur_y_test), max(cur_y_test)],
    [min(cur_y_test), max(cur_y_test)],
    color="red",
    linestyle="--",
    label="Diagonal (Ideal Prediction)",
)
plt.xlabel("Actual Stress Component")
plt.ylabel("Predicted Stress Component")
plt.title("Gradient Boosting Model Prediction vs Actual Data")
plt.legend()
plt.show()

# %% [markdown]
# ## С оптимизацией гиперпараметров

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import cross_val_score

n_splits = 3
# Preparing datasets
cur_X_test, cur_y_test, val_list_X, val_list_y, train_list_X, train_list_y = (
    split_transform_one_comp_cv(X, y, n_splits=n_splits)
)

def do_optuna_for_boosting(X, y, n_trials=100, **kwargs):
    n_splits = kwargs.get("n_splits", 3)

    def optuna_boosting_val(trial):
        n_estimators = trial.suggest_int("n_estimators", 50, 300)
        max_depth = trial.suggest_int("max_depth", 1, 10)
        learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-1, log=True)

        params = {
            "n_estimators": n_estimators,
            "max_depth": max_depth,
            "learning_rate": learning_rate,
            "random_state": RANDOM_STATE,
        }

        # Fitting and scoring `n_split` times
        errors = np.zeros((n_splits, 9))

        for split_idx in range(n_splits):
            regr = GradientBoostingRegressor(**params)

            cur_X_train = train_list_X[split_idx]
            cur_y_train = train_list_y[split_idx]

            cur_X_val = val_list_X[split_idx]
            cur_y_val = val_list_y[split_idx]

            cur_X_train, cur_y_train = clean_input_array(cur_X_train, cur_y_train)
            cur_X_val, cur_y_val = clean_input_array(cur_X_val, cur_y_val)

            regr.fit(cur_X_train, cur_y_train)

            #######  Validation  ########
            #  Prediction
            cur_prediction = regr.predict(cur_X_val)
            # Scoring
            errors[split_idx] = scorer(cur_y_val, cur_prediction, regr, cur_X_train)

        # Collect validation result
        val_metrics = choose_worst(errors)
        return_value = (
            val_metrics[-1] if pd.notnull(val_metrics[-1]) else +1e6
        )  # для rmse
        return return_value

    # Create a study object to optimize the objective
    study = optuna.create_study(direction="minimize")  # rmse
    study.optimize(optuna_boosting_val, n_trials=n_trials, n_jobs=-1)

    # Print the best hyperparameters found by Optuna
    best_params = study.best_params
    best_value = study.best_value
    print("Best Hyperparameters:", best_params)

    return best_params, cur_X_test, cur_y_test, best_value

# Use the function
best_params, cur_X_test, cur_y_test, best_value = do_optuna_for_boosting(X, y, n_splits=n_splits)

# Предсказание
model = GradientBoostingRegressor(**best_params, random_state=RANDOM_STATE)
model.fit(cur_X_train, cur_y_train)
cur_y_pred = model.predict(cur_X_test)

# Оценка качества
rmse = np.sqrt(mean_squared_error(cur_y_test, cur_y_pred))
print(f"RMSE test: {rmse:.2f}")

# На трейне
cur_y_pred_train = model.predict(cur_X_train)
rmse_train = np.sqrt(mean_squared_error(cur_y_train, cur_y_pred_train))
print(f"RMSE train: {rmse_train:.2f}")
# Out:
# [I 2025-03-02 00:27:03,149] A new study created in memory with name: no-name-801e570f-81fb-4805-8eb2-832af10c9dcc
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:08,007] Trial 4 finished with value: 30.140614541444045 and parameters: {'n_estimators': 251, 'max_depth': 1, 'learning_rate': 0.0562816623488786}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:08,484] Trial 3 finished with value: 45.3705798446044 and parameters: {'n_estimators': 274, 'max_depth': 1, 'learning_rate': 0.0025043889423723583}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:08,955] Trial 6 finished with value: 45.9086041290469 and parameters: {'n_estimators': 87, 'max_depth': 5, 'learning_rate': 0.003251172923466756}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:11,140] Trial 0 finished with value: 44.791419658381116 and parameters: {'n_estimators': 248, 'max_depth': 2, 'learning_rate': 0.001772936692431898}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:11,474] Trial 1 finished with value: 58.68497892078317 and parameters: {'n_estimators': 264, 'max_depth': 2, 'learning_rate': 0.00011574489183078973}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:11,641] Trial 10 finished with value: 30.156428154588824 and parameters: {'n_estimators': 151, 'max_depth': 1, 'learning_rate': 0.07256818147315103}. Best is trial 4 with value: 30.140614541444045.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:14,350] Trial 7 finished with value: 5.526646138110682 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.031033884130997776}. Best is trial 7 with value: 5.526646138110682.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:14,542] Trial 2 finished with value: 58.016099053026814 and parameters: {'n_estimators': 145, 'max_depth': 6, 'learning_rate': 0.00023464034100176964}. Best is trial 7 with value: 5.526646138110682.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:18,179] Trial 12 finished with value: 25.627222175694385 and parameters: {'n_estimators': 56, 'max_depth': 9, 'learning_rate': 0.01533163376458627}. Best is trial 7 with value: 5.526646138110682.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:18,586] Trial 5 finished with value: 1.4039993948625742 and parameters: {'n_estimators': 152, 'max_depth': 8, 'learning_rate': 0.09780188852235103}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:26,308] Trial 8 finished with value: 29.779701879669016 and parameters: {'n_estimators': 191, 'max_depth': 7, 'learning_rate': 0.003787132014389482}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:26,524] Trial 14 finished with value: 54.504498543740056 and parameters: {'n_estimators': 139, 'max_depth': 6, 'learning_rate': 0.0007087034505739954}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:28,237] Trial 9 finished with value: 3.0906471343633437 and parameters: {'n_estimators': 162, 'max_depth': 9, 'learning_rate': 0.021183102524062036}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:30,332] Trial 16 finished with value: 57.30055497016853 and parameters: {'n_estimators': 106, 'max_depth': 8, 'learning_rate': 0.00043465060789810747}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:36,045] Trial 13 finished with value: 11.396376398681287 and parameters: {'n_estimators': 277, 'max_depth': 6, 'learning_rate': 0.006829770061280668}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:38,978] Trial 11 finished with value: 7.241279621828763 and parameters: {'n_estimators': 202, 'max_depth': 10, 'learning_rate': 0.010801037049474207}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:42,161] Trial 15 finished with value: 41.03858118802747 and parameters: {'n_estimators': 199, 'max_depth': 10, 'learning_rate': 0.0019184862687235073}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:46,738] Trial 17 finished with value: 9.562873347215014 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.009397509743198983}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:51,596] Trial 18 finished with value: 2.2062813576474865 and parameters: {'n_estimators': 194, 'max_depth': 9, 'learning_rate': 0.022105591940563385}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:55,066] Trial 19 finished with value: 1.8242217818098423 and parameters: {'n_estimators': 201, 'max_depth': 10, 'learning_rate': 0.021669496389865907}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:55,162] Trial 24 finished with value: 4.651519645763465 and parameters: {'n_estimators': 110, 'max_depth': 8, 'learning_rate': 0.026661277399852953}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:56,893] Trial 20 finished with value: 5.369754956117733 and parameters: {'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.012613593476401268}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:27:59,440] Trial 21 finished with value: 7.623570936312983 and parameters: {'n_estimators': 202, 'max_depth': 10, 'learning_rate': 0.010519688794719581}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:00,372] Trial 25 finished with value: 4.5797849286425 and parameters: {'n_estimators': 114, 'max_depth': 8, 'learning_rate': 0.025970978839365846}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:05,467] Trial 22 finished with value: 2.2661894647460508 and parameters: {'n_estimators': 201, 'max_depth': 10, 'learning_rate': 0.018895063638812597}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:05,805] Trial 26 finished with value: 1.6452767973028495 and parameters: {'n_estimators': 116, 'max_depth': 8, 'learning_rate': 0.0874892857038321}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:11,255] Trial 23 finished with value: 1.5904397137865236 and parameters: {'n_estimators': 217, 'max_depth': 10, 'learning_rate': 0.023511827402013047}. Best is trial 5 with value: 1.4039993948625742.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:23,250] Trial 27 finished with value: 1.2871444003807708 and parameters: {'n_estimators': 224, 'max_depth': 8, 'learning_rate': 0.09276397832256528}. Best is trial 27 with value: 1.2871444003807708.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:24,548] Trial 28 finished with value: 1.622493507657262 and parameters: {'n_estimators': 233, 'max_depth': 8, 'learning_rate': 0.046156811889249895}. Best is trial 27 with value: 1.2871444003807708.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:25,416] Trial 29 finished with value: 1.3203052153587884 and parameters: {'n_estimators': 227, 'max_depth': 8, 'learning_rate': 0.0848141419034987}. Best is trial 27 with value: 1.2871444003807708.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:28,985] Trial 30 finished with value: 1.5988299902931957 and parameters: {'n_estimators': 236, 'max_depth': 8, 'learning_rate': 0.048375257114099214}. Best is trial 27 with value: 1.2871444003807708.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:31,580] Trial 33 finished with value: 2.0619823354882816 and parameters: {'n_estimators': 229, 'max_depth': 7, 'learning_rate': 0.05187067553391083}. Best is trial 27 with value: 1.2871444003807708.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:32,142] Trial 31 finished with value: 1.159541463135321 and parameters: {'n_estimators': 231, 'max_depth': 9, 'learning_rate': 0.09000058393239416}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:36,675] Trial 32 finished with value: 1.2869353527245808 and parameters: {'n_estimators': 223, 'max_depth': 9, 'learning_rate': 0.053162028641441525}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:37,276] Trial 34 finished with value: 1.6085038649997736 and parameters: {'n_estimators': 235, 'max_depth': 7, 'learning_rate': 0.09600102059491726}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:40,276] Trial 36 finished with value: 5.859315402099032 and parameters: {'n_estimators': 232, 'max_depth': 4, 'learning_rate': 0.04242148372742062}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:43,399] Trial 39 finished with value: 7.291589508203044 and parameters: {'n_estimators': 219, 'max_depth': 3, 'learning_rate': 0.08850914377123796}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:48,696] Trial 35 finished with value: 2.14581211434047 and parameters: {'n_estimators': 228, 'max_depth': 7, 'learning_rate': 0.04527069139304478}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:50,648] Trial 41 finished with value: 9.143769062594357 and parameters: {'n_estimators': 257, 'max_depth': 3, 'learning_rate': 0.03828157063688132}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:54,124] Trial 38 finished with value: 1.6146681957436806 and parameters: {'n_estimators': 226, 'max_depth': 7, 'learning_rate': 0.08865312425577915}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:57,891] Trial 37 finished with value: 1.5005877954029188 and parameters: {'n_estimators': 293, 'max_depth': 7, 'learning_rate': 0.09230504547679165}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:28:57,944] Trial 42 finished with value: 5.571569188819311 and parameters: {'n_estimators': 299, 'max_depth': 4, 'learning_rate': 0.03876494273544678}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:05,093] Trial 40 finished with value: 1.4423965623951587 and parameters: {'n_estimators': 298, 'max_depth': 7, 'learning_rate': 0.09911196153961983}. Best is trial 31 with value: 1.159541463135321.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:21,241] Trial 43 finished with value: 1.1322728199666516 and parameters: {'n_estimators': 297, 'max_depth': 9, 'learning_rate': 0.07537254756857213}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:22,311] Trial 48 finished with value: 1.3595821818515998 and parameters: {'n_estimators': 176, 'max_depth': 9, 'learning_rate': 0.05889548452421844}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:23,249] Trial 49 finished with value: 1.298921570499616 and parameters: {'n_estimators': 182, 'max_depth': 9, 'learning_rate': 0.06466295844308416}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:23,889] Trial 44 finished with value: 1.3634356488603534 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.03602745337931172}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:28,692] Trial 45 finished with value: 1.1527859808047094 and parameters: {'n_estimators': 291, 'max_depth': 9, 'learning_rate': 0.07013688822926252}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:30,265] Trial 46 finished with value: 1.147497837343094 and parameters: {'n_estimators': 289, 'max_depth': 9, 'learning_rate': 0.0682893868603}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:30,448] Trial 50 finished with value: 1.3248568991687626 and parameters: {'n_estimators': 183, 'max_depth': 9, 'learning_rate': 0.058440044745576895}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:33,649] Trial 47 finished with value: 1.1724850345337168 and parameters: {'n_estimators': 288, 'max_depth': 9, 'learning_rate': 0.06659225892671287}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:58,268] Trial 51 finished with value: 1.1818799362569037 and parameters: {'n_estimators': 270, 'max_depth': 9, 'learning_rate': 0.06312874447546839}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:59,431] Trial 52 finished with value: 1.206314540952677 and parameters: {'n_estimators': 273, 'max_depth': 9, 'learning_rate': 0.05850483454301006}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:29:59,910] Trial 53 finished with value: 1.2146801819788857 and parameters: {'n_estimators': 268, 'max_depth': 9, 'learning_rate': 0.06280627328113918}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:00,921] Trial 54 finished with value: 1.226921233903793 and parameters: {'n_estimators': 271, 'max_depth': 9, 'learning_rate': 0.056756815642413236}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:06,458] Trial 55 finished with value: 14.272591814118476 and parameters: {'n_estimators': 276, 'max_depth': 9, 'learning_rate': 0.005345902448601632}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:07,953] Trial 56 finished with value: 14.254601598171288 and parameters: {'n_estimators': 275, 'max_depth': 9, 'learning_rate': 0.005370193231214568}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:08,454] Trial 57 finished with value: 13.904335844489937 and parameters: {'n_estimators': 276, 'max_depth': 9, 'learning_rate': 0.0054467987256210625}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:10,906] Trial 58 finished with value: 57.125813743907386 and parameters: {'n_estimators': 274, 'max_depth': 9, 'learning_rate': 0.00017842662785969878}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:37,984] Trial 59 finished with value: 16.98664477750698 and parameters: {'n_estimators': 275, 'max_depth': 9, 'learning_rate': 0.004695304105337233}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:40,042] Trial 60 finished with value: 13.550560154689554 and parameters: {'n_estimators': 278, 'max_depth': 9, 'learning_rate': 0.005506719802055121}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:40,935] Trial 61 finished with value: 56.84301753940496 and parameters: {'n_estimators': 281, 'max_depth': 9, 'learning_rate': 0.00019179736542305678}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:46,957] Trial 62 finished with value: 46.14350075281464 and parameters: {'n_estimators': 283, 'max_depth': 10, 'learning_rate': 0.0009317782107378864}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:49,386] Trial 65 finished with value: 1.2829680297002244 and parameters: {'n_estimators': 246, 'max_depth': 10, 'learning_rate': 0.0324789474394533}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:54,625] Trial 63 finished with value: 58.24006885955291 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.00010213971200689728}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:55,569] Trial 64 finished with value: 57.47386108682247 and parameters: {'n_estimators': 285, 'max_depth': 10, 'learning_rate': 0.00014957927518655638}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:30:59,660] Trial 66 finished with value: 1.267388284276756 and parameters: {'n_estimators': 286, 'max_depth': 10, 'learning_rate': 0.02983195219525785}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:26,873] Trial 67 finished with value: 1.2810707402592774 and parameters: {'n_estimators': 246, 'max_depth': 10, 'learning_rate': 0.031767299908773035}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:30,544] Trial 69 finished with value: 1.278245605440884 and parameters: {'n_estimators': 246, 'max_depth': 10, 'learning_rate': 0.03300831359297744}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:41,221] Trial 68 finished with value: 48.87016640164158 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.0007172662904839346}. Best is trial 43 with value: 1.1322728199666516.
# [I 2025-03-02 00:31:41,677] Trial 70 finished with value: 1.319289729361598 and parameters: {'n_estimators': 247, 'max_depth': 10, 'learning_rate': 0.030203842988568035}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:44,191] Trial 72 finished with value: 1.338012308181479 and parameters: {'n_estimators': 259, 'max_depth': 8, 'learning_rate': 0.0702489782255455}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:46,270] Trial 73 finished with value: 1.3404118100976943 and parameters: {'n_estimators': 258, 'max_depth': 8, 'learning_rate': 0.07062324553579759}. Best is trial 43 with value: 1.1322728199666516.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:49,444] Trial 71 finished with value: 1.1156864920028615 and parameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.07123668319491888}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:31:57,374] Trial 74 finished with value: 1.3424521968324519 and parameters: {'n_estimators': 261, 'max_depth': 8, 'learning_rate': 0.07293685105817987}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:32:47,381] Trial 75 finished with value: 1.329799001842836 and parameters: {'n_estimators': 261, 'max_depth': 8, 'learning_rate': 0.07301732578614292}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:32:51,233] Trial 76 finished with value: 1.3431511841473271 and parameters: {'n_estimators': 254, 'max_depth': 8, 'learning_rate': 0.07051956110425259}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:32:59,787] Trial 77 finished with value: 1.3253877036614474 and parameters: {'n_estimators': 260, 'max_depth': 8, 'learning_rate': 0.069936292901631}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:01,700] Trial 78 finished with value: 1.3288324394180973 and parameters: {'n_estimators': 263, 'max_depth': 8, 'learning_rate': 0.07095872985680929}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:04,266] Trial 79 finished with value: 1.292033166039936 and parameters: {'n_estimators': 268, 'max_depth': 8, 'learning_rate': 0.07527279129012376}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:04,776] Trial 80 finished with value: 1.3265830466102217 and parameters: {'n_estimators': 267, 'max_depth': 8, 'learning_rate': 0.06949337488429094}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:05,492] Trial 81 finished with value: 2.7925188098289135 and parameters: {'n_estimators': 263, 'max_depth': 8, 'learning_rate': 0.01589589234194126}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:08,465] Trial 82 finished with value: 2.7578299808505595 and parameters: {'n_estimators': 254, 'max_depth': 8, 'learning_rate': 0.01679535038534539}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:44,085] Trial 83 finished with value: 2.6293300139046396 and parameters: {'n_estimators': 266, 'max_depth': 8, 'learning_rate': 0.016613114321893593}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:33:54,364] Trial 84 finished with value: 1.2836740106151328 and parameters: {'n_estimators': 266, 'max_depth': 9, 'learning_rate': 0.047529993630208316}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:07,281] Trial 85 finished with value: 1.2516028578380194 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.0447362465854926}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:08,981] Trial 86 finished with value: 2.160646597058968 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.015039721171928444}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:11,434] Trial 87 finished with value: 1.2865057706906444 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.04432209910774316}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:12,852] Trial 89 finished with value: 1.2504056480743841 and parameters: {'n_estimators': 292, 'max_depth': 9, 'learning_rate': 0.04686833722994751}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:34:12,868] Trial 88 finished with value: 1.260265057329749 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.047123269687061604}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:16,593] Trial 90 finished with value: 1.1927345528147082 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.051148422646766944}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:19,669] Trial 97 finished with value: 30.153766395133076 and parameters: {'n_estimators': 210, 'max_depth': 1, 'learning_rate': 0.05451548262132171}. Best is trial 71 with value: 1.1156864920028615.
# /var/folders/_d/tbsnrdk10zg3j0zy12r9dprw0000gq/T/ipykernel_99638/2579710447.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-4, 1e-1)
# [I 2025-03-02 00:34:33,524] Trial 95 finished with value: 3.501549971524663 and parameters: {'n_estimators': 133, 'max_depth': 6, 'learning_rate': 0.05466932183112517}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:34:50,494] Trial 91 finished with value: 1.2191191752501123 and parameters: {'n_estimators': 295, 'max_depth': 9, 'learning_rate': 0.04750321099062976}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:34:58,607] Trial 92 finished with value: 1.2724114710742256 and parameters: {'n_estimators': 293, 'max_depth': 9, 'learning_rate': 0.0419526264550857}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:34:59,127] Trial 96 finished with value: 2.378878651881881 and parameters: {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.05503382140221035}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:35:01,392] Trial 94 finished with value: 1.2863763173791767 and parameters: {'n_estimators': 240, 'max_depth': 9, 'learning_rate': 0.05382709606709307}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:35:12,215] Trial 93 finished with value: 1.221156104707305 and parameters: {'n_estimators': 298, 'max_depth': 9, 'learning_rate': 0.05004066623678982}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:35:19,701] Trial 98 finished with value: 1.1647006587225102 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.057506878997337495}. Best is trial 71 with value: 1.1156864920028615.
# [I 2025-03-02 00:35:21,837] Trial 99 finished with value: 1.1333529224674788 and parameters: {'n_estimators': 299, 'max_depth': 9, 'learning_rate': 0.08347576830650978}. Best is trial 71 with value: 1.1156864920028615.
# Best Hyperparameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.07123668319491888}
# RMSE test: 1.06
# RMSE train: 0.38

# %%
import joblib
# Best Hyperparameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.07123668319491888}
best_params = {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.07123668319491888}
# Train the model with the best hyperparameters
model = GradientBoostingRegressor(**best_params, random_state=RANDOM_STATE)
cur_X_train = train_list_X[-1]
cur_y_train = train_list_y[-1]
model.fit(cur_X_train, cur_y_train)

pred = model.predict(cur_X_test)
rmse = np.sqrt(mean_squared_error(cur_y_test, pred))
print(f"RMSE Test: {rmse:.2f}")


pred = model.predict(cur_X_train)
rmse = np.sqrt(mean_squared_error(cur_y_train, pred))
print(f"RMSE Train: {rmse:.2f}")


# Save the model to a file
model_filename = "best_gradient_boosting_model.pkl"
joblib.dump(model, model_filename)
print(f"Model saved to {model_filename}")
# Out:
# RMSE Test: 0.88
# RMSE Train: 0.39
# Model saved to best_gradient_boosting_model.pkl

# %%
import matplotlib.pyplot as plt

# Predicting the values
cur_y_pred = model.predict(cur_X_test)

# Plotting the results
plt.figure(figsize=(7, 6))
plt.scatter(cur_y_test, cur_y_pred, alpha=0.5, label="Predicted vs Actual")
plt.plot(
    [min(cur_y_test), max(cur_y_test)],
    [min(cur_y_test), max(cur_y_test)],
    color="red",
    linestyle="--",
    label="Diagonal (Ideal Prediction)",
)
plt.xlabel("Actual Stress Component")
plt.ylabel("Predicted Stress Component")
plt.title("Gradient Boosting Model Prediction vs Actual Data")
plt.legend()
plt.show()
